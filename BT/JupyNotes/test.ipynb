# %%
# %jsroot on

# %%
import ROOT
jsroot.download("myhist.html", h, "colz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58136/458252612.py in <module>
#       1 import ROOT
# ----> 2 jsroot.download("myhist.html", h, "colz")
#
# NameError: name 'jsroot' is not defined

# %%
c = ROOT.TCanvas()
f = ROOT.TF1("f1", "sin(x)/x", 0., 10.)
f.Draw()
c.Draw()
# Out:
# <div id="root_plot_1765281701643"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1765281701643(Core) {
# ...

# %%
jsroot.download
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58136/632277223.py in <module>
# ----> 1 jsroot.download
#
# NameError: name 'jsroot' is not defined
